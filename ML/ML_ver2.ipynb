# %%
import pandas as pd
import numpy as np
import sklearn

# %%
#import datasets as dataframes
aqi_2000df = pd.read_csv(r'resources/daily_aqi_by_county_2000.csv', low_memory=False)
display(aqi_2000df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin         01            3  2000-01-16   25
# 1         Alabama     Baldwin         01            3  2000-01-19   46
# 2         Alabama     Baldwin         01            3  2000-01-22   36
# 3         Alabama     Baldwin         01            3  2000-01-25   26
# 4         Alabama     Baldwin         01            3  2000-01-28   32
# ...           ...         ...        ...          ...         ...  ...
# 272765    Wyoming       Teton         56           39  2000-12-27   37
# 272766    Wyoming       Teton         56           39  2000-12-28   38
# 272767    Wyoming       Teton         56           39  2000-12-29   42
# 272768    Wyoming       Teton         56           39  2000-12-30   42
# 272769    Wyoming       Teton         56           39  2000-12-31   37
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
#drop unnecesary collumns
aqi_2000df1=aqi_2000df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2000df1)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2000-01-16   25
# 1         Alabama     Baldwin         01            3  2000-01-19   46
# 2         Alabama     Baldwin         01            3  2000-01-22   36
# 3         Alabama     Baldwin         01            3  2000-01-25   26
# 4         Alabama     Baldwin         01            3  2000-01-28   32
# ...           ...         ...        ...          ...         ...  ...
# 272765    Wyoming       Teton         56           39  2000-12-27   37
# 272766    Wyoming       Teton         56           39  2000-12-28   38
# 272767    Wyoming       Teton         56           39  2000-12-29   42
# 272768    Wyoming       Teton         56           39  2000-12-30   42
# 272769    Wyoming       Teton         56           39  2000-12-31   37
#
# [272770 rows x 6 columns]

# %%
#repeat process for years 2001-2016
aqi_2001df = pd.read_csv(r'resources/daily_aqi_by_county_2001.csv', low_memory=False)
display(aqi_2001df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin         01            3  2001-01-01   38
# 1         Alabama     Baldwin         01            3  2001-01-04   23
# 2         Alabama     Baldwin         01            3  2001-01-07   52
# 3         Alabama     Baldwin         01            3  2001-01-10   52
# 4         Alabama     Baldwin         01            3  2001-01-19   17
# ...           ...         ...        ...          ...         ...  ...
# 281386    Wyoming       Teton         56           39  2001-12-27   43
# 281387    Wyoming       Teton         56           39  2001-12-28   42
# 281388    Wyoming       Teton         56           39  2001-12-29   40
# 281389    Wyoming       Teton         56           39  2001-12-30   54
# 281390    Wyoming       Teton         56           39  2001-12-31   42
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2001df1=aqi_2001df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2001df1)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2001-01-01   38
# 1         Alabama     Baldwin         01            3  2001-01-04   23
# 2         Alabama     Baldwin         01            3  2001-01-07   52
# 3         Alabama     Baldwin         01            3  2001-01-10   52
# 4         Alabama     Baldwin         01            3  2001-01-19   17
# ...           ...         ...        ...          ...         ...  ...
# 281386    Wyoming       Teton         56           39  2001-12-27   43
# 281387    Wyoming       Teton         56           39  2001-12-28   42
# 281388    Wyoming       Teton         56           39  2001-12-29   40
# 281389    Wyoming       Teton         56           39  2001-12-30   54
# 281390    Wyoming       Teton         56           39  2001-12-31   42
#
# [281391 rows x 6 columns]

# %%
aqi_2002df = pd.read_csv(r'resources/daily_aqi_by_county_2002.csv', low_memory=False)
display(aqi_2002df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin         01            3  2002-01-02   52
# 1         Alabama     Baldwin         01            3  2002-01-05   52
# 2         Alabama     Baldwin         01            3  2002-01-08   30
# 3         Alabama     Baldwin         01            3  2002-01-11   28
# 4         Alabama     Baldwin         01            3  2002-01-14   24
# ...           ...         ...        ...          ...         ...  ...
# 286901    Wyoming       Teton         56           39  2002-12-27   36
# 286902    Wyoming       Teton         56           39  2002-12-28   34
# 286903    Wyoming       Teton         56           39  2002-12-29   40
# 286904    Wyoming       Teton         56           39  2002-12-30   40
# 286905    Wyoming       Teton         56           39  2002-12-31   39
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2002df1=aqi_2002df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2002df1)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2002-01-02   52
# 1         Alabama     Baldwin         01            3  2002-01-05   52
# 2         Alabama     Baldwin         01            3  2002-01-08   30
# 3         Alabama     Baldwin         01            3  2002-01-11   28
# 4         Alabama     Baldwin         01            3  2002-01-14   24
# ...           ...         ...        ...          ...         ...  ...
# 286901    Wyoming       Teton         56           39  2002-12-27   36
# 286902    Wyoming       Teton         56           39  2002-12-28   34
# 286903    Wyoming       Teton         56           39  2002-12-29   40
# 286904    Wyoming       Teton         56           39  2002-12-30   40
# 286905    Wyoming       Teton         56           39  2002-12-31   39
#
# [286906 rows x 6 columns]

# %%
aqi_2003df = pd.read_csv(r'resources/daily_aqi_by_county_2003.csv', low_memory=False)
display(aqi_2003df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin         01            3  2003-01-03   30
# 1         Alabama     Baldwin         01            3  2003-01-06   30
# 2         Alabama     Baldwin         01            3  2003-01-09   51
# 3         Alabama     Baldwin         01            3  2003-01-12   28
# 4         Alabama     Baldwin         01            3  2003-01-15   64
# ...           ...         ...        ...          ...         ...  ...
# 290538    Wyoming       Teton         56           39  2003-12-27   35
# 290539    Wyoming       Teton         56           39  2003-12-28   37
# 290540    Wyoming       Teton         56           39  2003-12-29   39
# 290541    Wyoming       Teton         56           39  2003-12-30    3
# 290542    Wyoming       Teton         56           39  2003-12-31    2
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2003df1=aqi_2003df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2003df1)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2003-01-03   30
# 1         Alabama     Baldwin         01            3  2003-01-06   30
# 2         Alabama     Baldwin         01            3  2003-01-09   51
# 3         Alabama     Baldwin         01            3  2003-01-12   28
# 4         Alabama     Baldwin         01            3  2003-01-15   64
# ...           ...         ...        ...          ...         ...  ...
# 290538    Wyoming       Teton         56           39  2003-12-27   35
# 290539    Wyoming       Teton         56           39  2003-12-28   37
# 290540    Wyoming       Teton         56           39  2003-12-29   39
# 290541    Wyoming       Teton         56           39  2003-12-30    3
# 290542    Wyoming       Teton         56           39  2003-12-31    2
#
# [290543 rows x 6 columns]

# %%
aqi_2004df = pd.read_csv(r'resources/daily_aqi_by_county_2004.csv', low_memory=False)
display(aqi_2004df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin         01            3  2004-01-01   64
# 1         Alabama     Baldwin         01            3  2004-01-04   17
# 2         Alabama     Baldwin         01            3  2004-01-07   23
# 3         Alabama     Baldwin         01            3  2004-01-10   60
# 4         Alabama     Baldwin         01            3  2004-01-13   60
# ...           ...         ...        ...          ...         ...  ...
# 298484    Wyoming       Teton         56           39  2004-12-27   36
# 298485    Wyoming       Teton         56           39  2004-12-28   37
# 298486    Wyoming       Teton         56           39  2004-12-29   38
# 298487    Wyoming       Teton         56           39  2004-12-30   43
# 298488    Wyoming       Teton         56           39  2004-12-31   42
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2004df1=aqi_2004df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2004df1)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2004-01-01   64
# 1         Alabama     Baldwin         01            3  2004-01-04   17
# 2         Alabama     Baldwin         01            3  2004-01-07   23
# 3         Alabama     Baldwin         01            3  2004-01-10   60
# 4         Alabama     Baldwin         01            3  2004-01-13   60
# ...           ...         ...        ...          ...         ...  ...
# 298484    Wyoming       Teton         56           39  2004-12-27   36
# 298485    Wyoming       Teton         56           39  2004-12-28   37
# 298486    Wyoming       Teton         56           39  2004-12-29   38
# 298487    Wyoming       Teton         56           39  2004-12-30   43
# 298488    Wyoming       Teton         56           39  2004-12-31   42
#
# [298489 rows x 6 columns]

# %%
aqi_2005df = pd.read_csv(r'resources/daily_aqi_by_county_2005.csv', low_memory=False)
display(aqi_2005df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin         01            3  2005-01-01   38
# 1         Alabama     Baldwin         01            3  2005-01-04   32
# 2         Alabama     Baldwin         01            3  2005-01-07   30
# 3         Alabama     Baldwin         01            3  2005-01-10   36
# 4         Alabama     Baldwin         01            3  2005-01-13   14
# ...           ...         ...        ...          ...         ...  ...
# 301664    Wyoming       Teton         56           39  2005-12-27   41
# 301665    Wyoming       Teton         56           39  2005-12-28   43
# 301666    Wyoming       Teton         56           39  2005-12-29   44
# 301667    Wyoming       Teton         56           39  2005-12-30   40
# 301668    Wyoming       Teton         56           39  2005-12-31    2
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2005df1=aqi_2005df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2005df1)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2005-01-01   38
# 1         Alabama     Baldwin         01            3  2005-01-04   32
# 2         Alabama     Baldwin         01            3  2005-01-07   30
# 3         Alabama     Baldwin         01            3  2005-01-10   36
# 4         Alabama     Baldwin         01            3  2005-01-13   14
# ...           ...         ...        ...          ...         ...  ...
# 301664    Wyoming       Teton         56           39  2005-12-27   41
# 301665    Wyoming       Teton         56           39  2005-12-28   43
# 301666    Wyoming       Teton         56           39  2005-12-29   44
# 301667    Wyoming       Teton         56           39  2005-12-30   40
# 301668    Wyoming       Teton         56           39  2005-12-31    2
#
# [301669 rows x 6 columns]

# %%
aqi_2006df = pd.read_csv(r'resources/daily_aqi_by_county_2006.csv', low_memory=False)
display(aqi_2006df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin         01            3  2006-01-02   50
# 1         Alabama     Baldwin         01            3  2006-01-05   41
# 2         Alabama     Baldwin         01            3  2006-01-08   39
# 3         Alabama     Baldwin         01            3  2006-01-11   29
# 4         Alabama     Baldwin         01            3  2006-01-14   20
# ...           ...         ...        ...          ...         ...  ...
# 302936    Wyoming       Teton         56           39  2006-12-27   31
# 302937    Wyoming       Teton         56           39  2006-12-28   31
# 302938    Wyoming       Teton         56           39  2006-12-29   29
# 302939    Wyoming       Teton         56           39  2006-12-30   35
# 302940    Wyoming       Teton         56           39  2006-12-31   47
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2006df1=aqi_2006df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2006df1)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2006-01-02   50
# 1         Alabama     Baldwin         01            3  2006-01-05   41
# 2         Alabama     Baldwin         01            3  2006-01-08   39
# 3         Alabama     Baldwin         01            3  2006-01-11   29
# 4         Alabama     Baldwin         01            3  2006-01-14   20
# ...           ...         ...        ...          ...         ...  ...
# 302936    Wyoming       Teton         56           39  2006-12-27   31
# 302937    Wyoming       Teton         56           39  2006-12-28   31
# 302938    Wyoming       Teton         56           39  2006-12-29   29
# 302939    Wyoming       Teton         56           39  2006-12-30   35
# 302940    Wyoming       Teton         56           39  2006-12-31   47
#
# [302941 rows x 6 columns]

# %%
aqi_2007df = pd.read_csv(r'resources/daily_aqi_by_county_2007.csv', low_memory=False)
display(aqi_2007df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2007-01-03   55
# 1         Alabama     Baldwin           1            3  2007-01-06   23
# 2         Alabama     Baldwin           1            3  2007-01-09   13
# 3         Alabama     Baldwin           1            3  2007-01-12   25
# 4         Alabama     Baldwin           1            3  2007-01-15   17
# ...           ...         ...         ...          ...         ...  ...
# 309104    Wyoming       Uinta          56           41  2007-12-27   33
# 309105    Wyoming       Uinta          56           41  2007-12-28   34
# 309106    Wyoming       Uinta          56           41  2007-12-29   35
# 309107    Wyoming       Uinta          56           41  2007-12-30   36
# 309108    Wyoming       Uinta          56           41  2007-12-31   34
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2007df1=aqi_2007df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2007df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2007-01-03   55
# 1         Alabama     Baldwin           1            3  2007-01-06   23
# 2         Alabama     Baldwin           1            3  2007-01-09   13
# 3         Alabama     Baldwin           1            3  2007-01-12   25
# 4         Alabama     Baldwin           1            3  2007-01-15   17
# ...           ...         ...         ...          ...         ...  ...
# 309104    Wyoming       Uinta          56           41  2007-12-27   33
# 309105    Wyoming       Uinta          56           41  2007-12-28   34
# 309106    Wyoming       Uinta          56           41  2007-12-29   35
# 309107    Wyoming       Uinta          56           41  2007-12-30   36
# 309108    Wyoming       Uinta          56           41  2007-12-31   34
#
# [309109 rows x 6 columns]

# %%
aqi_2008df = pd.read_csv(r'resources/daily_aqi_by_county_2008.csv', low_memory=False)
display(aqi_2008df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2008-01-04   38
# 1         Alabama     Baldwin           1            3  2008-01-07   15
# 2         Alabama     Baldwin           1            3  2008-01-10   15
# 3         Alabama     Baldwin           1            3  2008-01-13   38
# 4         Alabama     Baldwin           1            3  2008-01-16   31
# ...           ...         ...         ...          ...         ...  ...
# 310390    Wyoming       Uinta          56           41  2008-12-27   35
# 310391    Wyoming       Uinta          56           41  2008-12-28   36
# 310392    Wyoming       Uinta          56           41  2008-12-29   33
# 310393    Wyoming       Uinta          56           41  2008-12-30   37
# 310394    Wyoming       Uinta          56           41  2008-12-31   38
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2008df1=aqi_2008df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2008df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2008-01-04   38
# 1         Alabama     Baldwin           1            3  2008-01-07   15
# 2         Alabama     Baldwin           1            3  2008-01-10   15
# 3         Alabama     Baldwin           1            3  2008-01-13   38
# 4         Alabama     Baldwin           1            3  2008-01-16   31
# ...           ...         ...         ...          ...         ...  ...
# 310390    Wyoming       Uinta          56           41  2008-12-27   35
# 310391    Wyoming       Uinta          56           41  2008-12-28   36
# 310392    Wyoming       Uinta          56           41  2008-12-29   33
# 310393    Wyoming       Uinta          56           41  2008-12-30   37
# 310394    Wyoming       Uinta          56           41  2008-12-31   38
#
# [310395 rows x 6 columns]

# %%
aqi_2009df = pd.read_csv(r'resources/daily_aqi_by_county_2009.csv', low_memory=False)
display(aqi_2009df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2009-03-05   56
# 1         Alabama     Baldwin           1            3  2009-03-08   18
# 2         Alabama     Baldwin           1            3  2009-03-10   31
# 3         Alabama     Baldwin           1            3  2009-03-11   28
# 4         Alabama     Baldwin           1            3  2009-03-12   30
# ...           ...         ...         ...          ...         ...  ...
# 315614    Wyoming       Uinta          56           41  2009-12-27   35
# 315615    Wyoming       Uinta          56           41  2009-12-28   34
# 315616    Wyoming       Uinta          56           41  2009-12-29   33
# 315617    Wyoming       Uinta          56           41  2009-12-30   33
# 315618    Wyoming       Uinta          56           41  2009-12-31   36
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2009df1=aqi_2009df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2009df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2009-03-05   56
# 1         Alabama     Baldwin           1            3  2009-03-08   18
# 2         Alabama     Baldwin           1            3  2009-03-10   31
# 3         Alabama     Baldwin           1            3  2009-03-11   28
# 4         Alabama     Baldwin           1            3  2009-03-12   30
# ...           ...         ...         ...          ...         ...  ...
# 315614    Wyoming       Uinta          56           41  2009-12-27   35
# 315615    Wyoming       Uinta          56           41  2009-12-28   34
# 315616    Wyoming       Uinta          56           41  2009-12-29   33
# 315617    Wyoming       Uinta          56           41  2009-12-30   33
# 315618    Wyoming       Uinta          56           41  2009-12-31   36
#
# [315619 rows x 6 columns]

# %%
aqi_2010df = pd.read_csv(r'resources/daily_aqi_by_county_2010.csv', low_memory=False)
display(aqi_2010df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2010-01-02   25
# 1         Alabama     Baldwin           1            3  2010-01-05   31
# 2         Alabama     Baldwin           1            3  2010-01-08   23
# 3         Alabama     Baldwin           1            3  2010-01-11   32
# 4         Alabama     Baldwin           1            3  2010-01-14   56
# ...           ...         ...         ...          ...         ...  ...
# 320853    Wyoming       Uinta          56           41  2010-12-27   41
# 320854    Wyoming       Uinta          56           41  2010-12-28   37
# 320855    Wyoming       Uinta          56           41  2010-12-29   40
# 320856    Wyoming       Uinta          56           41  2010-12-30   38
# 320857    Wyoming       Uinta          56           41  2010-12-31   35
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2010df1=aqi_2010df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2010df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2010-01-02   25
# 1         Alabama     Baldwin           1            3  2010-01-05   31
# 2         Alabama     Baldwin           1            3  2010-01-08   23
# 3         Alabama     Baldwin           1            3  2010-01-11   32
# 4         Alabama     Baldwin           1            3  2010-01-14   56
# ...           ...         ...         ...          ...         ...  ...
# 320853    Wyoming       Uinta          56           41  2010-12-27   41
# 320854    Wyoming       Uinta          56           41  2010-12-28   37
# 320855    Wyoming       Uinta          56           41  2010-12-29   40
# 320856    Wyoming       Uinta          56           41  2010-12-30   38
# 320857    Wyoming       Uinta          56           41  2010-12-31   35
#
# [320858 rows x 6 columns]

# %%
aqi_2011df = pd.read_csv(r'resources/daily_aqi_by_county_2011.csv', low_memory=False)
display(aqi_2011df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2011-01-03   25
# 1         Alabama     Baldwin           1            3  2011-01-06   42
# 2         Alabama     Baldwin           1            3  2011-01-09   25
# 3         Alabama     Baldwin           1            3  2011-01-12   25
# 4         Alabama     Baldwin           1            3  2011-01-15   59
# ...           ...         ...         ...          ...         ...  ...
# 319306    Wyoming       Uinta          56           41  2011-12-27   35
# 319307    Wyoming       Uinta          56           41  2011-12-28   35
# 319308    Wyoming       Uinta          56           41  2011-12-29   31
# 319309    Wyoming       Uinta          56           41  2011-12-30   34
# 319310    Wyoming       Uinta          56           41  2011-12-31   34
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2011df1=aqi_2011df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2011df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2011-01-03   25
# 1         Alabama     Baldwin           1            3  2011-01-06   42
# 2         Alabama     Baldwin           1            3  2011-01-09   25
# 3         Alabama     Baldwin           1            3  2011-01-12   25
# 4         Alabama     Baldwin           1            3  2011-01-15   59
# ...           ...         ...         ...          ...         ...  ...
# 319306    Wyoming       Uinta          56           41  2011-12-27   35
# 319307    Wyoming       Uinta          56           41  2011-12-28   35
# 319308    Wyoming       Uinta          56           41  2011-12-29   31
# 319309    Wyoming       Uinta          56           41  2011-12-30   34
# 319310    Wyoming       Uinta          56           41  2011-12-31   34
#
# [319311 rows x 6 columns]

# %%
aqi_2012df = pd.read_csv(r'resources/daily_aqi_by_county_2012.csv', low_memory=False)
display(aqi_2012df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2012-01-01   28
# 1         Alabama     Baldwin           1            3  2012-01-04   38
# 2         Alabama     Baldwin           1            3  2012-01-07   27
# 3         Alabama     Baldwin           1            3  2012-01-10   29
# 4         Alabama     Baldwin           1            3  2012-01-13   24
# ...           ...         ...         ...          ...         ...  ...
# 319226    Wyoming      Weston          56           45  2012-12-27   34
# 319227    Wyoming      Weston          56           45  2012-12-28   37
# 319228    Wyoming      Weston          56           45  2012-12-29   41
# 319229    Wyoming      Weston          56           45  2012-12-30   40
# 319230    Wyoming      Weston          56           45  2012-12-31   41
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2012df1=aqi_2012df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2012df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2012-01-01   28
# 1         Alabama     Baldwin           1            3  2012-01-04   38
# 2         Alabama     Baldwin           1            3  2012-01-07   27
# 3         Alabama     Baldwin           1            3  2012-01-10   29
# 4         Alabama     Baldwin           1            3  2012-01-13   24
# ...           ...         ...         ...          ...         ...  ...
# 319226    Wyoming      Weston          56           45  2012-12-27   34
# 319227    Wyoming      Weston          56           45  2012-12-28   37
# 319228    Wyoming      Weston          56           45  2012-12-29   41
# 319229    Wyoming      Weston          56           45  2012-12-30   40
# 319230    Wyoming      Weston          56           45  2012-12-31   41
#
# [319231 rows x 6 columns]

# %%
aqi_2013df = pd.read_csv(r'resources/daily_aqi_by_county_2013.csv', low_memory=False)
display(aqi_2013df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2013-01-01   30
# 1         Alabama     Baldwin           1            3  2013-01-04   32
# 2         Alabama     Baldwin           1            3  2013-01-07   36
# 3         Alabama     Baldwin           1            3  2013-01-10   29
# 4         Alabama     Baldwin           1            3  2013-01-13   30
# ...           ...         ...         ...          ...         ...  ...
# 318181    Wyoming      Weston          56           45  2013-12-27   35
# 318182    Wyoming      Weston          56           45  2013-12-28   35
# 318183    Wyoming      Weston          56           45  2013-12-29   35
# 318184    Wyoming      Weston          56           45  2013-12-30   36
# 318185    Wyoming      Weston          56           45  2013-12-31   37
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2013df1=aqi_2013df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2013df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2013-01-01   30
# 1         Alabama     Baldwin           1            3  2013-01-04   32
# 2         Alabama     Baldwin           1            3  2013-01-07   36
# 3         Alabama     Baldwin           1            3  2013-01-10   29
# 4         Alabama     Baldwin           1            3  2013-01-13   30
# ...           ...         ...         ...          ...         ...  ...
# 318181    Wyoming      Weston          56           45  2013-12-27   35
# 318182    Wyoming      Weston          56           45  2013-12-28   35
# 318183    Wyoming      Weston          56           45  2013-12-29   35
# 318184    Wyoming      Weston          56           45  2013-12-30   36
# 318185    Wyoming      Weston          56           45  2013-12-31   37
#
# [318186 rows x 6 columns]

# %%
aqi_2014df = pd.read_csv(r'resources/daily_aqi_by_county_2014.csv', low_memory=False)
display(aqi_2014df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2014-01-02   33
# 1         Alabama     Baldwin           1            3  2014-01-05   29
# 2         Alabama     Baldwin           1            3  2014-01-08   29
# 3         Alabama     Baldwin           1            3  2014-01-11   15
# 4         Alabama     Baldwin           1            3  2014-01-14   22
# ...           ...         ...         ...          ...         ...  ...
# 318854    Wyoming      Weston          56           45  2014-12-27   30
# 318855    Wyoming      Weston          56           45  2014-12-28   32
# 318856    Wyoming      Weston          56           45  2014-12-29   30
# 318857    Wyoming      Weston          56           45  2014-12-30   31
# 318858    Wyoming      Weston          56           45  2014-12-31   36
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2014df1=aqi_2014df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2014df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2014-01-02   33
# 1         Alabama     Baldwin           1            3  2014-01-05   29
# 2         Alabama     Baldwin           1            3  2014-01-08   29
# 3         Alabama     Baldwin           1            3  2014-01-11   15
# 4         Alabama     Baldwin           1            3  2014-01-14   22
# ...           ...         ...         ...          ...         ...  ...
# 318854    Wyoming      Weston          56           45  2014-12-27   30
# 318855    Wyoming      Weston          56           45  2014-12-28   32
# 318856    Wyoming      Weston          56           45  2014-12-29   30
# 318857    Wyoming      Weston          56           45  2014-12-30   31
# 318858    Wyoming      Weston          56           45  2014-12-31   36
#
# [318859 rows x 6 columns]

# %%
aqi_2015df = pd.read_csv(r'resources/daily_aqi_by_county_2015.csv', low_memory=False)
display(aqi_2015df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2015-01-03   28
# 1         Alabama     Baldwin           1            3  2015-01-06   48
# 2         Alabama     Baldwin           1            3  2015-01-09   55
# 3         Alabama     Baldwin           1            3  2015-01-12   41
# 4         Alabama     Baldwin           1            3  2015-01-15   26
# ...           ...         ...         ...          ...         ...  ...
# 320530    Wyoming      Weston          56           45  2015-12-27   39
# 320531    Wyoming      Weston          56           45  2015-12-28   36
# 320532    Wyoming      Weston          56           45  2015-12-29   33
# 320533    Wyoming      Weston          56           45  2015-12-30   35
# 320534    Wyoming      Weston          56           45  2015-12-31   36
#
#         Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2015df1=aqi_2015df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2015df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2015-01-03   28
# 1         Alabama     Baldwin           1            3  2015-01-06   48
# 2         Alabama     Baldwin           1            3  2015-01-09   55
# 3         Alabama     Baldwin           1            3  2015-01-12   41
# 4         Alabama     Baldwin           1            3  2015-01-15   26
# ...           ...         ...         ...          ...         ...  ...
# 320530    Wyoming      Weston          56           45  2015-12-27   39
# 320531    Wyoming      Weston          56           45  2015-12-28   36
# 320532    Wyoming      Weston          56           45  2015-12-29   33
# 320533    Wyoming      Weston          56           45  2015-12-30   35
# 320534    Wyoming      Weston          56           45  2015-12-31   36
#
# [320535 rows x 6 columns]

# %%
aqi_2016df = pd.read_csv(r'resources/daily_aqi_by_county_2016.csv', low_memory=False)
display(aqi_2016df)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 0         Alabama     Baldwin           1            3  2016-01-01   33
# 1         Alabama     Baldwin           1            3  2016-01-04   22
# 2         Alabama     Baldwin           1            3  2016-01-07   28
# 3         Alabama     Baldwin           1            3  2016-01-10   13
# 4         Alabama     Baldwin           1            3  2016-01-13   36
# ...           ...         ...         ...          ...         ...  ...
# 321066    Wyoming      Weston          56           45  2016-12-27   43
# 321067    Wyoming      Weston          56           45  2016-12-28   42
# 321068    Wyoming      Weston          56           45  2016-12-29   39
# 321069    Wyoming      Weston          56           45  2016-12-30   40
# 321070    Wyoming      Weston          56           45  2016-12-31   39
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# ...

# %%
aqi_2016df1=aqi_2016df.drop(columns=['Category', 'Defining Parameter', 'Defining Site', 'Number of Sites Reporting'])
display(aqi_2016df1)
# Out:
#        State Name county Name  State Code  County Code        Date  AQI
# 0         Alabama     Baldwin           1            3  2016-01-01   33
# 1         Alabama     Baldwin           1            3  2016-01-04   22
# 2         Alabama     Baldwin           1            3  2016-01-07   28
# 3         Alabama     Baldwin           1            3  2016-01-10   13
# 4         Alabama     Baldwin           1            3  2016-01-13   36
# ...           ...         ...         ...          ...         ...  ...
# 321066    Wyoming      Weston          56           45  2016-12-27   43
# 321067    Wyoming      Weston          56           45  2016-12-28   42
# 321068    Wyoming      Weston          56           45  2016-12-29   39
# 321069    Wyoming      Weston          56           45  2016-12-30   40
# 321070    Wyoming      Weston          56           45  2016-12-31   39
#
# [321071 rows x 6 columns]

# %%
#smush all the annual aqi into one 
frames = [aqi_2000df1, aqi_2001df1, aqi_2002df1, aqi_2003df1, aqi_2004df1, aqi_2005df1, aqi_2006df1, aqi_2007df1, aqi_2008df1, aqi_2009df1, aqi_2010df1, aqi_2011df1, aqi_2012df1, aqi_2013df1, aqi_2014df1, aqi_2015df1, aqi_2016df1]
aqi_df = pd.concat(frames)
display(aqi_df)
# Out:
#        State Name county Name State Code  County Code        Date  AQI
# 0         Alabama     Baldwin         01            3  2000-01-16   25
# 1         Alabama     Baldwin         01            3  2000-01-19   46
# 2         Alabama     Baldwin         01            3  2000-01-22   36
# 3         Alabama     Baldwin         01            3  2000-01-25   26
# 4         Alabama     Baldwin         01            3  2000-01-28   32
# ...           ...         ...        ...          ...         ...  ...
# 321066    Wyoming      Weston         56           45  2016-12-27   43
# 321067    Wyoming      Weston         56           45  2016-12-28   42
# 321068    Wyoming      Weston         56           45  2016-12-29   39
# 321069    Wyoming      Weston         56           45  2016-12-30   40
# 321070    Wyoming      Weston         56           45  2016-12-31   39
#
# [5207883 rows x 6 columns]

# %%
#reanme collumns to match pollution dataset
aqi_df1= aqi_df.rename(columns = {'State Name':'usstate', 'county Name':'county','Date':'local_date'})
display(aqi_df1)
# Out:
#         usstate   county State Code  County Code  local_date  AQI
# 0       Alabama  Baldwin         01            3  2000-01-16   25
# 1       Alabama  Baldwin         01            3  2000-01-19   46
# 2       Alabama  Baldwin         01            3  2000-01-22   36
# 3       Alabama  Baldwin         01            3  2000-01-25   26
# 4       Alabama  Baldwin         01            3  2000-01-28   32
# ...         ...      ...        ...          ...         ...  ...
# 321066  Wyoming   Weston         56           45  2016-12-27   43
# 321067  Wyoming   Weston         56           45  2016-12-28   42
# 321068  Wyoming   Weston         56           45  2016-12-29   39
# 321069  Wyoming   Weston         56           45  2016-12-30   40
# 321070  Wyoming   Weston         56           45  2016-12-31   39
#
# [5207883 rows x 6 columns]

# %%
#Clean up the pollutant data
pollution_df = pd.read_csv(r'resources/us_pollution_2000_2016.csv')
display(pollution_df)
# Out:
#          usstate   county           city  local_date    no2avg  no2maxvalue  \
# 0       New York  Steuben  Not in a city  2009-06-11  2.468182          4.5
# 1       New York  Steuben  Not in a city  2009-06-12  1.533333          2.0
# 2       New York  Steuben  Not in a city  2009-06-13  1.445455          2.2
# 3       New York  Steuben  Not in a city  2009-06-14  1.119048          1.5
# 4       New York  Steuben  Not in a city  2009-06-15  1.636364          2.9
# ...          ...      ...            ...         ...       ...          ...
# 436871  New York  Steuben  Not in a city  2009-06-06  1.875000          4.5
# 436872  New York  Steuben  Not in a city  2009-06-07  2.431579          3.9
# 436873  New York  Steuben  Not in a city  2009-06-08  2.920833          5.0
# 436874  New York  Steuben  Not in a city  2009-06-09  1.759091          2.8
# 436875  New York  Steuben  Not in a city  2009-06-10  2.500000          4.2
#
# ...

# %%
#drop unneeded columns, EPA focuses on the highest level of pollutant reported so I adjusted the dataframe to reflect this
pdf1= pollution_df.drop(columns=['no2avg', 'no2maxhour', 'no2aqi', 'o3avg', 'o3maxhour', 'o3aqi', 'so2avg', 'so2maxhour', 'so2aqi', 'coavg', 'comaxhour', 'coaqi'])
display(pdf1)
# Out:
#          usstate   county           city  local_date  no2maxvalue  o3maxvalue  \
# 0       New York  Steuben  Not in a city  2009-06-11          4.5       0.033
# 1       New York  Steuben  Not in a city  2009-06-12          2.0       0.032
# 2       New York  Steuben  Not in a city  2009-06-13          2.2       0.034
# 3       New York  Steuben  Not in a city  2009-06-14          1.5       0.039
# 4       New York  Steuben  Not in a city  2009-06-15          2.9       0.052
# ...          ...      ...            ...         ...          ...         ...
# 436871  New York  Steuben  Not in a city  2009-06-06          4.5       0.055
# 436872  New York  Steuben  Not in a city  2009-06-07          3.9       0.040
# 436873  New York  Steuben  Not in a city  2009-06-08          5.0       0.029
# 436874  New York  Steuben  Not in a city  2009-06-09          2.8       0.048
# 436875  New York  Steuben  Not in a city  2009-06-10          4.2       0.042
#
#         so2maxvalue  comaxvalue
# ...

# %%
#drop extra date rows, since I am only focusing on the highest value from each day
pdf2= pdf1.drop_duplicates(subset=['usstate', 'county', 'city', 'local_date'])
display(pdf2)
# Out:
#          usstate   county           city  local_date  no2maxvalue  o3maxvalue  \
# 0       New York  Steuben  Not in a city  2009-06-11          4.5       0.033
# 1       New York  Steuben  Not in a city  2009-06-12          2.0       0.032
# 2       New York  Steuben  Not in a city  2009-06-13          2.2       0.034
# 3       New York  Steuben  Not in a city  2009-06-14          1.5       0.039
# 4       New York  Steuben  Not in a city  2009-06-15          2.9       0.052
# ...          ...      ...            ...         ...          ...         ...
# 436871  New York  Steuben  Not in a city  2009-06-06          4.5       0.055
# 436872  New York  Steuben  Not in a city  2009-06-07          3.9       0.040
# 436873  New York  Steuben  Not in a city  2009-06-08          5.0       0.029
# 436874  New York  Steuben  Not in a city  2009-06-09          2.8       0.048
# 436875  New York  Steuben  Not in a city  2009-06-10          4.2       0.042
#
#         so2maxvalue  comaxvalue
# ...

# %%
#drop rows not in a city
pdf3= pdf2[pdf2.city !='Not in a city']
display(pdf3)
# Out:
#          usstate    county      city  local_date  no2maxvalue  o3maxvalue  \
# 136      Arizona  Maricopa   Phoenix  2000-01-01         49.0       0.040
# 137      Arizona  Maricopa   Phoenix  2000-01-02         36.0       0.032
# 138      Arizona  Maricopa   Phoenix  2000-01-03         51.0       0.016
# 139      Arizona  Maricopa   Phoenix  2000-01-04         74.0       0.033
# 140      Arizona  Maricopa   Phoenix  2000-01-05         61.0       0.012
# ...          ...       ...       ...         ...          ...         ...
# 436714  New York    Queens  New York  2009-12-27         41.0       0.030
# 436715  New York    Queens  New York  2009-12-28         45.0       0.018
# 436716  New York    Queens  New York  2009-12-29         21.0       0.029
# 436717  New York    Queens  New York  2009-12-30         42.0       0.013
# 436718  New York    Queens  New York  2009-12-31         43.0       0.006
#
#         so2maxvalue  comaxvalue
# 136             9.0         2.2
# ...

# %%
merged_df=pd.merge(pdf3, aqi_df1, on=['usstate', 'county', 'local_date'], how='inner')
display(merged_df)
# Out:
#          usstate    county        city  local_date  no2maxvalue  o3maxvalue  \
# 0        Arizona  Maricopa     Phoenix  2000-01-01         49.0       0.040
# 1        Arizona  Maricopa  Scottsdale  2000-01-01        102.0       0.039
# 2        Arizona  Maricopa     Phoenix  2000-01-02         36.0       0.032
# 3        Arizona  Maricopa  Scottsdale  2000-01-02         79.0       0.027
# 4        Arizona  Maricopa     Phoenix  2000-01-03         51.0       0.016
# ...          ...       ...         ...         ...          ...         ...
# 361257  New York    Queens    New York  2009-12-27         41.0       0.030
# 361258  New York    Queens    New York  2009-12-28         45.0       0.018
# 361259  New York    Queens    New York  2009-12-29         21.0       0.029
# 361260  New York    Queens    New York  2009-12-30         42.0       0.013
# 361261  New York    Queens    New York  2009-12-31         43.0       0.006
#
# ...

# %%
#save master dataframe to csv
#from pathlib import Path
#filepath1 = Path('ML/resources/master_df.csv')
#filepath1.parent.mkdir(parents=True, exist_ok=True)
#merged_df.to_csv(filepath1, index=False)

# %%
#import census data
census_df1 = pd.read_csv(r'resources/census_2000s.csv')
display(census_df1)
# Out:
#                        city       usstate  POPESTIMATE2000  POPESTIMATE2001  \
# 0                   Alabama       Alabama          4452173          4467634
# 1            Abbeville city       Alabama             2985             2941
# 2           Adamsville city       Alabama             5021             4960
# 3              Addison town       Alabama              701              701
# 4                Akron town       Alabama              485              473
# ...                     ...           ...              ...              ...
# 81620    Central Falls city  Rhode Island            19017            19183
# 81621         Cranston city  Rhode Island            79440            80047
# 81622         Cranston city  Rhode Island            79440            80047
# 81623  East Providence city  Rhode Island            48734            48897
# 81624  East Providence city  Rhode Island            48734            48897
#
# ...

# %%
census_df2 = pd.read_csv(r'resources/census_2010s.csv')
display(census_df2)
# Out:
#                           city       usstate  POPESTIMATE2011  \
# 0           Bloomfield borough  Pennsylvania             1248
# 1           Bloomfield borough  Pennsylvania             1248
# 2             Buffalo township  Pennsylvania             1211
# 3             Carroll township  Pennsylvania             5264
# 4              Centre township  Pennsylvania             2499
# ...                        ...           ...              ...
# 81410      New Buffalo borough  Pennsylvania              124
# 81411          Newport borough  Pennsylvania             1574
# 81412  Balance of Perry County  Pennsylvania            36831
# 81413            Blain borough  Pennsylvania              260
# 81414            Blain borough  Pennsylvania              260
#
#        POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# 0                 1244             1241             1243             1246
# ...

# %%
#merge census data frames
census_mdf = pd.merge(census_df1, census_df2, on=['city', 'usstate'], how='inner')
display(census_mdf)
# Out:
#                          city       usstate  POPESTIMATE2000  POPESTIMATE2001  \
# 0                     Alabama       Alabama          4452173          4467634
# 1              Abbeville city       Alabama             2985             2941
# 2              Abbeville city       Alabama             2985             2941
# 3              Abbeville city       Alabama             2985             2941
# 4              Abbeville city       Alabama             2985             2941
# ...                       ...           ...              ...              ...
# 223059           Lincoln town  Rhode Island            20901            21068
# 223060  North Providence town  Rhode Island            32500            32683
# 223061  North Smithfield town  Rhode Island            10729            10930
# 223062          Scituate town  Rhode Island            10205            10289
# 223063        Smithfield town  Rhode Island            20696            20884
#
# ...

# %%
#drop collumns 2017-2020
census_mdf1= census_mdf.drop(columns=['POPESTIMATE2017', 'POPESTIMATE2018', 'POPESTIMATE2019', 'POPESTIMATE2020'])
display(census_mdf1)
# Out:
#                          city       usstate  POPESTIMATE2000  POPESTIMATE2001  \
# 0                     Alabama       Alabama          4452173          4467634
# 1              Abbeville city       Alabama             2985             2941
# 2              Abbeville city       Alabama             2985             2941
# 3              Abbeville city       Alabama             2985             2941
# 4              Abbeville city       Alabama             2985             2941
# ...                       ...           ...              ...              ...
# 223059           Lincoln town  Rhode Island            20901            21068
# 223060  North Providence town  Rhode Island            32500            32683
# 223061  North Smithfield town  Rhode Island            10729            10930
# 223062          Scituate town  Rhode Island            10205            10289
# 223063        Smithfield town  Rhode Island            20696            20884
#
# ...

# %%
merged_df.dtypes
# Out:
# usstate         object
# county          object
# city            object
# local_date      object
# no2maxvalue    float64
# o3maxvalue     float64
# so2maxvalue    float64
# comaxvalue     float64
# State Code      object
# County Code      int64
# AQI              int64
# dtype: object

# %%
merged_df= merged_df.astype({'State Code':'int'})
merged_df.dtypes
# Out:
# usstate         object
# county          object
# city            object
# local_date      object
# no2maxvalue    float64
# o3maxvalue     float64
# so2maxvalue    float64
# comaxvalue     float64
# State Code       int32
# County Code      int64
# AQI              int64
# dtype: object

# %%
merged_df= merged_df.rename(columns={'State Code':'state_code', 'County Code':'county_code'})
display(merged_df)
# Out:
#          usstate    county        city  local_date  no2maxvalue  o3maxvalue  \
# 0        Arizona  Maricopa     Phoenix  2000-01-01         49.0       0.040
# 1        Arizona  Maricopa  Scottsdale  2000-01-01        102.0       0.039
# 2        Arizona  Maricopa     Phoenix  2000-01-02         36.0       0.032
# 3        Arizona  Maricopa  Scottsdale  2000-01-02         79.0       0.027
# 4        Arizona  Maricopa     Phoenix  2000-01-03         51.0       0.016
# ...          ...       ...         ...         ...          ...         ...
# 361257  New York    Queens    New York  2009-12-27         41.0       0.030
# 361258  New York    Queens    New York  2009-12-28         45.0       0.018
# 361259  New York    Queens    New York  2009-12-29         21.0       0.029
# 361260  New York    Queens    New York  2009-12-30         42.0       0.013
# 361261  New York    Queens    New York  2009-12-31         43.0       0.006
#
# ...

# %%
#filter dataset to display a specific city. Excel file with city, sate name and code info in resources
#I will test Los Angeles(037) county in California(06)  
la_df = merged_df[(merged_df.state_code ==6)&(merged_df.county_code ==37)]
display(la_df)
# Out:
#            usstate       county         city  local_date  no2maxvalue  \
# 4188    California  Los Angeles      Burbank  2000-01-01         41.0
# 4189    California  Los Angeles   Long Beach  2000-01-01         44.0
# 4190    California  Los Angeles    Hawthorne  2000-01-01         46.0
# 4191    California  Los Angeles      Burbank  2000-01-02         32.0
# 4192    California  Los Angeles   Long Beach  2000-01-02         46.0
# ...            ...          ...          ...         ...          ...
# 350498  California  Los Angeles   Long Beach  2009-12-13         19.0
# 350499  California  Los Angeles  Los Angeles  2009-12-14         42.0
# 350500  California  Los Angeles   Long Beach  2009-12-14         44.0
# 350501  California  Los Angeles  Los Angeles  2009-12-22         45.0
# 350502  California  Los Angeles   Long Beach  2009-12-22         44.0
#
#         o3maxvalue  so2maxvalue  comaxvalue  state_code  county_code  AQI
# ...

# %%
#drop string columns and convert local_date to integer to prep for machine learning model
la_ml_df1 = la_df.drop(columns=['usstate', 'county', 'city'])
display(la_ml_df1)
# Out:
#         local_date  no2maxvalue  o3maxvalue  so2maxvalue  comaxvalue  \
# 4188    2000-01-01         41.0       0.028          0.0         3.0
# 4189    2000-01-01         44.0       0.015          3.0         2.0
# 4190    2000-01-01         46.0       0.035          3.0         4.0
# 4191    2000-01-02         32.0       0.040          0.0         0.8
# 4192    2000-01-02         46.0       0.033          2.0         0.6
# ...            ...          ...         ...          ...         ...
# 350498  2009-12-13         19.0       0.035          2.0         0.3
# 350499  2009-12-14         42.0       0.018          1.0         1.1
# 350500  2009-12-14         44.0       0.013          5.0         1.0
# 350501  2009-12-22         45.0       0.037          1.0         1.2
# 350502  2009-12-22         44.0       0.034          2.0         1.0
#
#         state_code  county_code  AQI
# 4188             6           37  158
# 4189             6           37  158
# ...

# %%
la_ml_df1['local_date'] = la_ml_df1['local_date'].str.replace("-","")
display(la_ml_df1)
# Out:
#        local_date  no2maxvalue  o3maxvalue  so2maxvalue  comaxvalue  \
# 4188     20000101         41.0       0.028          0.0         3.0
# 4189     20000101         44.0       0.015          3.0         2.0
# 4190     20000101         46.0       0.035          3.0         4.0
# 4191     20000102         32.0       0.040          0.0         0.8
# 4192     20000102         46.0       0.033          2.0         0.6
# ...           ...          ...         ...          ...         ...
# 350498   20091213         19.0       0.035          2.0         0.3
# 350499   20091214         42.0       0.018          1.0         1.1
# 350500   20091214         44.0       0.013          5.0         1.0
# 350501   20091222         45.0       0.037          1.0         1.2
# 350502   20091222         44.0       0.034          2.0         1.0
#
#         state_code  county_code  AQI
# 4188             6           37  158
# 4189             6           37  158
# ...

# %%
la_ml_df2 = la_ml_df1.astype({'local_date':'int'})
display(la_ml_df2)
# Out:
#         local_date  no2maxvalue  o3maxvalue  so2maxvalue  comaxvalue  \
# 4188      20000101         41.0       0.028          0.0         3.0
# 4189      20000101         44.0       0.015          3.0         2.0
# 4190      20000101         46.0       0.035          3.0         4.0
# 4191      20000102         32.0       0.040          0.0         0.8
# 4192      20000102         46.0       0.033          2.0         0.6
# ...            ...          ...         ...          ...         ...
# 350498    20091213         19.0       0.035          2.0         0.3
# 350499    20091214         42.0       0.018          1.0         1.1
# 350500    20091214         44.0       0.013          5.0         1.0
# 350501    20091222         45.0       0.037          1.0         1.2
# 350502    20091222         44.0       0.034          2.0         1.0
#
#         state_code  county_code  AQI
# 4188             6           37  158
# 4189             6           37  158
# ...

# %%
la_ml_df2.dtypes
# Out:
# local_date       int32
# no2maxvalue    float64
# o3maxvalue     float64
# so2maxvalue    float64
# comaxvalue     float64
# state_code       int32
# county_code      int64
# AQI              int64
# dtype: object

# %%
from pandas.plotting import scatter_matrix
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %%
#Separate clean dataframe into features and target variable 
X = la_ml_df2[['no2maxvalue', 'o3maxvalue', 'so2maxvalue', 'comaxvalue']].values
y = la_ml_df2['AQI'].values

# %%
#normalize or scale(using min max scaler) data
scaler = MinMaxScaler()
scaled = scaler.fit_transform(X,y)
display(scaled)
# Out:
# array([[0.15260736, 0.21875   , 0.00060569, 0.44594595],
#        [0.16411043, 0.1171875 , 0.0187765 , 0.31081081],
#        [0.17177914, 0.2734375 , 0.0187765 , 0.58108108],
#        ...,
#        [0.16411043, 0.1015625 , 0.03089037, 0.17567568],
#        [0.16794479, 0.2890625 , 0.00666263, 0.2027027 ],
#        [0.16411043, 0.265625  , 0.01271956, 0.17567568]])

# %%
#Separate clean dataframe into features and target variable 
X = scaled[['no2maxvalue', 'o3maxvalue', 'so2maxvalue', 'comaxvalue']].values
y = scaled['AQI'].values
# Out:
# C:\Users\julia\AppData\Local\Temp/ipykernel_1976/4233648333.py:2: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X = scaled[['no2maxvalue', 'o3maxvalue', 'so2maxvalue', 'comaxvalue']].values
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1976/4233648333.py in <module>
#       1 #Separate clean dataframe into features and target variable
# ----> 2 X = scaled[['no2maxvalue', 'o3maxvalue', 'so2maxvalue', 'comaxvalue']].values
#       3 y = scaled['AQI'].values
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
#Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
#Linear regression model 
from sklearn.linear_model import LinearRegression
lin_regr = LinearRegression()
lin_regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin_regr.predict(X_test)
print(y_pred)
# Out:
# [100.37042089  78.87102369 129.33770959 ...  81.52724089 101.84134234
#   81.41056309]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.28514204892135553

# %%
pred_y_df = pd.DataFrame({'Actual Value':y_test, 'Predicted Value':y_pred, 'Difference': y_test-y_pred})
display(pred_y_df)
# Out:
#       Actual Value  Predicted Value  Difference
# 0               58       100.370421  -42.370421
# 1               70        78.871024   -8.871024
# 2              154       129.337710   24.662290
# 3               35        72.347373  -37.347373
# 4               53        84.764969  -31.764969
# ...            ...              ...         ...
# 5275           133        97.517871   35.482129
# 5276           161       105.471202   55.528798
# 5277           129        81.527241   47.472759
# 5278            69       101.841342  -32.841342
# 5279            47        81.410563  -34.410563
#
# [5280 rows x 3 columns]

# %%
plt.scatter(la_ml_df2['no2maxvalue'], la_ml_df2['AQI'])
plt.xlabel('NO2 Max Value')
plt.ylabel('AQI')
plt.title('NO2 Max Value vs. AQI')
plt.show()

# %%
plt.scatter(la_ml_df2['o3maxvalue'], la_ml_df2['AQI'])
plt.xlabel('O3 Max Value')
plt.ylabel('AQI')
plt.title('O3 Max Value vs. AQI')
plt.show()

# %%
plt.scatter(la_ml_df2['so2maxvalue'], la_ml_df2['AQI'])
plt.xlabel('SO2 Max Value')
plt.ylabel('AQI')
plt.title('SO2 Max Value vs. AQI')
plt.show()

# %%
plt.scatter(la_ml_df2['comaxvalue'], la_ml_df2['AQI'])
plt.xlabel('CO Max Value')
plt.ylabel('AQI')
plt.title('CO Max Value vs. AQI')
plt.show()
